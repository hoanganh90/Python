# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
X=iris.data
Y=iris.target
feature_names = iris.feature_names
target_names = iris.target_names

# %%
#Split data
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.5)
print(X_train.shape) # Print how many rows and columns depends on test_size value
# Out:
# (75, 4)

# %%
# Use KNeighborsClassifier training model
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, Y_train)
y_pred = knn.predict(X_test)

# %%
#5 - Check the output
from sklearn import metrics
print(metrics.accuracy_score(Y_test, y_pred))
# Out:
# 0.9466666666666667

# %%
# Use DecisionTreeClassifier training model
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(X_train, Y_train)
y_pred = dtc.predict(X_test)

# %%
#5 - Check the output
from sklearn import metrics
print(metrics.accuracy_score(Y_test, y_pred))
# Out:
# 0.9866666666666667

# %%
sample = [[3,5,4,2], [2,3,5,4]]
predictions = knn.predict(sample)
pred_species = [iris.target_names[p] for p in predictions]
print("predictions: ", pred_species)
# Out:
# predictions:  [np.str_('versicolor'), np.str_('virginica')]

# %%
import joblib
joblib.dump(knn, 'mlbrain.joblib') # Store the train model in a binary file
# Out:
# ['mlbrain.joblib']

# %%
model = joblib.load('mlbrain.joblib') # Load the joblib model -> anytime may the training, then load the model from here
model.predict(X_test)
sample = [[3,5,4,2], [2,3,5,4]]
predictions = model.predict(sample)
pred_species = [iris.target_names[p] for p in predictions]
print("predictions: ", pred_species)
# Out:
# predictions:  [np.str_('versicolor'), np.str_('virginica')]
